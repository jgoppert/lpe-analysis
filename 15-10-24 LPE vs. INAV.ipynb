# %%
import px4tools
import pandas
import pylab as pl
# %matplotlib inline
pl.rcParams['figure.figsize'] = (15,5)
pl.rcParams['lines.linewidth'] = 3

# %%
data_inav = px4tools.project_lat_lon(px4tools.process_data(pandas.read_csv('logs/15-10-24-20_25_00.csv')))

# %%
data_lpe = px4tools.project_lat_lon(px4tools.process_data(pandas.read_csv('logs/15-10-24-20_46_53.csv')))

# %%
pl.figure(figsize=(10,10))
px4tools.pos_analysis(data_inav[70:95]);
pl.axis('equal')
# Out:
# (-4.0, 8.0, -5.0, 25.0)

# %%
pl.figure(figsize=(10,10))
px4tools.pos_analysis(data_lpe[10:40]);
pl.axis('equal')
# Out:
# (-6.0, 8.0, -5.0, 25.0)

# %%
px4tools.alt_analysis(data_lpe);

# %%
px4tools.alt_analysis(data_inav);

# %%
px4tools.plot_position_loops(data_inav)

# %%
px4tools.plot_position_loops(data_lpe)

# %%
data1 = data_lpe
data1.EST0_s6.plot(label='b_x')
data1.EST0_s7.plot(label='b_y')
data1.EST0_s8.plot(label='b_z')
pl.legend(loc='best', ncol=3)
pl.title('bias estimates')
pl.grid()
